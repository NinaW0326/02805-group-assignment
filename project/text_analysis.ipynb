# %%
# !pip install snownlp
# !pip install -U textblob
# !python -m textblob.download_corpora
# !pip install --upgrade gensim
# Out:
# Requirement already satisfied: snownlp in d:\programdata\anaconda3\lib\site-packages (0.12.3)
# Requirement already up-to-date: textblob in d:\programdata\anaconda3\lib\site-packages (0.15.3)
# Requirement already satisfied, skipping upgrade: nltk>=3.1 in d:\programdata\anaconda3\lib\site-packages (from textblob) (3.4.5)
# Requirement already satisfied, skipping upgrade: six in d:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.14.0)
# Finished.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\98292\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\98292\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\98292\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\98292\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\98292\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\98292\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Requirement already up-to-date: gensim in d:\programdata\anaconda3\lib\site-packages (3.8.3)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in d:\programdata\anaconda3\lib\site-packages (from gensim) (1.14.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in d:\programdata\anaconda3\lib\site-packages (from gensim) (1.4.1)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in d:\programdata\anaconda3\lib\site-packages (from gensim) (4.0.1)
# Requirement already satisfied, skipping upgrade: Cython==0.29.14 in d:\programdata\anaconda3\lib\site-packages (from gensim) (0.29.14)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in d:\programdata\anaconda3\lib\site-packages (from gensim) (1.18.1)

# %%
import numpy as np
import pandas as pd

# %%
# read text from local
book = open('book.txt').read()
len(book)
# Out:
# 6350912

# %%
# read characters json from local
characters = open('nodes_egdes.json').read()
len(characters)
# Out:
# 2267437

# %%
import json

characters = json.loads(str(characters))
characters = characters.keys()
len(characters)
# Out:
# 4264

# %%
character_list = list(characters)
char_list = []
for character in character_list:
    char_list.append(character.lower().replace('_',' '))
character_list = char_list
print('done!')
# Out:
# done!

# %%
# assign the sentences to particular characters
# 1. accoring to punctuations divide book to lists of sentences
import re

sentences_book = re.split("(?<=[.!?])\s+", book.lower()) 
len(sentences_book)
# Out:
# 73963

# %%
sentences_book[90]
# Out:
# 'or harold.'

# %%
import string
import nltk
from nltk.corpus import stopwords
import nltk.stem

s = nltk.stem.SnowballStemmer('english') 

for character in character_list:
    try:
        content = ''
        for sentence in sentences_book:
            if character in sentence:
#                 sentence = [s.stem(ws) for ws in sentence]                                                # extract stem of words
#                 sentence = (nltk.pos_tag(sentence))
#                 string_sentence = ''
#                 for word in sentence:
#                     if(word[1] in ['JJ','JJR','JJS','RB','RBR','RBS','VB','VBD','VBG','VBN','VBP','WRB']):
#                         string_sentence += word[0]+':'+word[1]+' '
#                 sentence = ' '.join(sentence)
                content += sentence+'\n'
        if len(content) != 0:
            path = 'data\{}.txt'.format(character)
            f = open(path, 'a', encoding ='utf-8')
            f.write(content)
            f.close()
    except: 
        pass
        
print('done!')
# Out:
# done!

# %%
# for some important characters
# harry potter
character = 'harry potter '
names = ['harry','potter']
content = ''
path = 'data\{}.txt'.format(character)
for sentence in sentences_book:
    for name in names:
        if name in sentence:
            content += sentence + '\n'
            continue
            
if len(content) > 0: 
    print('rewirting...')
    f = open(path, 'w', encoding ='utf-8') # overwirte
    f.write(content)
    f.close()
    
content = ''
print('done!')
# Out:
# rewirting...
# done!

# %%
# sentiment analysis
import os
from textblob import TextBlob

sentiment_dict = {}
filepath = './data/'
files = os.listdir(filepath) # get all the txt names
for file in files:
    path = filepath+file
    f = open(path,'r', encoding = 'utf-8')
    text = f.read()
    blob = TextBlob(text)
    positive_score = blob.sentiment.polarity
    sentiment_dict[file.strip('.txt')] = (positive_score,len(text))
print('done!')
# Out:
# done!

# %%
sentiment_dict= dict(sorted(sentiment_dict.items(), key=lambda item:item[1][1], reverse = True))
sentiment_dict
# Out:
# {'harry potter ': (0.047559626875090084, 2303703),
#  'red': (0.04478780690628627, 1006470),
#  'ed': (0.04270345589625881, 949513),
#  'king': (0.03997229719653255, 761314),
#  'ned': (0.04306473957487204, 683615),
#  'ar': (0.05555541951101124, 612432),
#  'im': (0.055140294630084366, 336876),
#  'wand': (0.05613186352451601, 277432),
#  'professor': (0.040584688198189875, 266152),
#  'will': (0.09699899343631932, 198428),
#  'hall': (0.13515373722527807, 151117),
#  'om': (0.019374669665947662, 104830),
#  'name': (0.09506994325826616, 100235),
#  'dan': (-0.032986081011607965, 88737),
#  'bell': (0.03520268075397687, 84612),
#  'follo': (0.04768860620968184, 81026),
#  'coun': (0.06262827450327454, 57974),
#  'dementor': (0.04262806928790112, 51304),
#  'dudley': (0.051922291692512244, 50787),
#  'harry potter': (0.10033955956870409, 48843),
#  'mark': (0.061201898006436634, 48620),
#  'dobby': (0.0406244363120481, 44640),
#  'minister': (0.12697125906887624, 43966),
#  'snake': (-0.00712498328569757, 40453),
#  'goyle': (0.010570716969345013, 39948),
#  'kreacher': (0.000221465474252082, 38271),
#  'portrai': (0.009075559687105666, 37600),
#  'gian': (0.004441368700162675, 35442),
#  'horcru': (0.005386486819413665, 34807),
#  'cedric': (0.05350920829029972, 34506),
#  'roll': (0.020586843540123224, 34158),
#  'crabbe': (0.01006165177583972, 33228),
#  'mina': (0.06497843582380436, 32917),
#  'hedwig': (0.01897106434641845, 27854),
#  'angel': (0.0580200163562432, 26270),
#  'chas': (0.07584070721192608, 22920),
#  'roy': (0.015695032007635442, 22820),
#  'peeves': (0.002318937351956215, 21756),
#  'fang': (-0.0010654687805225352, 21326),
#  'crookshanks': (0.020637750391113617, 20598),
#  'god': (0.06540491085569483, 19708),
#  'brown': (0.018852807364498014, 18374),
#  'arthur': (0.09073581149753022, 17300),
#  'rita skeeter': (0.03500768196834185, 16983),
#  'house-elf': (0.07382431886896171, 16745),
#  'prime minister': (0.05855633268600559, 16574),
#  'centaur': (0.051095756673881644, 16290),
#  'griphook': (0.021988519200952707, 16248),
#  'auror': (0.1748771615771615, 15418),
#  'winky': (-0.015316969797941336, 15094),
#  'buckbeak': (0.06961072781385282, 14984),
#  'draco malfoy': (0.01278607871720118, 14441),
#  'albus dumbledore': (0.07706218119735563, 13795),
#  'prince': (0.10744588744588744, 12812),
#  'bush': (-0.013710139311991174, 12395),
#  'gringo': (0.08084200088106341, 12246),
#  'werewolf': (0.05358551696619878, 11886),
#  'do': (0.04350035573993909, 11575),
#  'frank': (0.0560029734575189, 11517),
#  'grawp': (-0.03806974304250209, 11331),
#  'lucius malfoy': (0.0266710292022792, 10266),
#  'international': (0.13560361681329425, 10208),
#  'ubbly': (0.11122849139655862, 10174),
#  'jack': (0.09882362586908044, 10158),
#  'fat lady': (0.008900857852129039, 10075),
#  'firenze': (0.07627523809523805, 9837),
#  'muggle-born': (0.11135493685272449, 9766),
#  'lion': (0.04849156399156399, 9514),
#  'hestral': (0.019603954942300817, 9311),
#  'lee jordan': (0.11493922358505693, 9231),
#  'sirius black': (-0.05033673198146887, 9159),
#  'u': (0.07563482733741353, 9024),
#  'fawkes': (0.00613450604122246, 8989),
#  'nigel': (0.08311565726614271, 8741),
#  'commen': (0.1003881258859135, 8726),
#  'dark mark': (-0.0756222607202086, 8359),
#  'george weasley': (0.15041545414462076, 7984),
#  'borgin': (0.04180059523809526, 7639),
#  'knigh': (-0.01996419944789511, 7612),
#  'sorting ha': (0.0788264417574762, 7580),
#  'eagle': (0.07004310408949582, 7446),
#  'lestrange': (-0.02012324523898599, 7431),
#  'muriel': (0.15803435529462925, 7314),
#  'basil': (0.04170566502463055, 7299),
#  'rosmerta': (-0.0058392434988179635, 7249),
#  'half-blood': (0.05608901515151517, 7158),
#  'fluffy': (-0.0821381886087768, 7065),
#  'om riddle': (0.05807048561999054, 7000),
#  'katie bell': (0.14026065313412872, 6979),
#  'goblet of fire': (0.11362220877051388, 6919),
#  'cornelius fudge': (0.056213732330237166, 6877),
#  'pansy parkinson': (0.05516339869281047, 6860),
#  'unicorn': (0.021786841630591636, 6421),
#  'healer': (0.03705357142857144, 6377),
#  'asha': (0.02050157370809544, 6374),
#  'minerva': (0.007300657242063498, 6354),
#  'finn': (0.026741293532338315, 6285),
#  'pike': (0.03967889071337346, 6157),
#  'john': (0.20996693121693116, 6090),
#  'bob': (0.01128179384203481, 6015),
#  'opinion': (0.083952850877193, 5976),
#  'gargoyle': (-0.07213615749330037, 5956),
#  'dean thomas': (0.15346984336114766, 5930),
#  'savage': (0.0992063492063492, 5536),
#  'aragog': (-0.01857237339380198, 5329),
#  'michael': (0.013738839285714316, 5309),
#  'peter': (-0.012301136363636361, 5289),
#  'horace': (0.05654111371324488, 5250),
#  'luna lovegood': (0.10757243487506647, 5226),
#  'merlin': (0.08986341154819415, 5226),
#  'lavender brown': (0.0863425925925926, 5187),
#  'bean': (0.029196359678130515, 5166),
#  'viktor krum': (0.05125, 5122),
#  'pure-blood': (0.14795582706766916, 5119),
#  'hermione granger': (0.12541666666666662, 5091),
#  'snowy': (0.09745508459794175, 5059),
#  'dolores umbridge': (-0.0812979797979798, 4963),
#  'cedric diggory': (0.08185019102027295, 4842),
#  'zacharias smith': (0.06403721278721279, 4798),
#  'seamus finnigan': (0.05514184397163121, 4788),
#  'health': (0.10474296536796532, 4747),
#  'ravers': (-0.002971085518255333, 4687),
#  'severus snape': (0.02731638951877048, 4674),
#  "marauder's map": (0.08190883190883191, 4646),
#  'bagsho': (0.21134615384615388, 4513),
#  'neville longbottom': (0.05549195062416214, 4490),
#  'ugga': (0.03589126984126983, 4486),
#  'bellatrix lestrange': (-0.028351462879524114, 4459),
#  'gilderoy lockhar': (0.13999160561660556, 4348),
#  'bane': (0.03427832244008715, 4294),
#  'squib': (-0.025359083850931684, 4262),
#  'alicia spinne': (0.09527724049000642, 4223),
#  'malkin': (0.007328944203944208, 3986),
#  'arthur weasley': (0.13289877946127945, 3958),
#  'finch': (0.028049076773566578, 3908),
#  'bathilda bagsho': (0.20599415204678367, 3901),
#  'fred and george weasley': (0.04569083694083695, 3890),
#  'michael corner': (0.03943495514147692, 3855),
#  'nagini': (0.08758230452674896, 3838),
#  'oliver wood': (0.15506756756756754, 3834),
#  'wool': (0.022244537869537867, 3830),
#  'kingsley shacklebol': (0.12880328583453585, 3828),
#  'fleur delacour': (0.1252742763772175, 3772),
#  'seer': (0.06996416546416546, 3719),
#  'no': (0.029246031746031756, 3688),
#  'abbo': (-0.07973484848484849, 3623),
#  'fred weasley': (0.06696687860750362, 3594),
#  'leprechaun': (0.10073099415204677, 3474),
#  'parvati patil': (0.0770255499860763, 3459),
#  'zonko': (0.1441942719116632, 3428),
#  'mandrake': (0.09491013071895427, 3294),
#  'parseltongue': (0.037084009740259744, 3294),
#  'viole': (0.038763227513227506, 3258),
#  'marsh': (0.08593153759820425, 3251),
#  'wandmaker': (0.06969198790627364, 3248),
#  'percy weasley': (0.08374741200828156, 3245),
#  'dennis': (0.056940498737373724, 3162),
#  'hannah abbo': (-0.06578231292517006, 3126),
#  'games': (0.17210656990068757, 3076),
#  'dirk': (0.09687328954570332, 3071),
#  'badger': (-0.03537414965986395, 2916),
#  'argus filch': (0.0466991341991342, 2900),
#  'rufus scrimgeour': (0.1505316321105795, 2880),
#  'angelina johnson': (0.22900958994708995, 2790),
#  'mundungus fletcher': (0.17721306471306472, 2712),
#  'errol': (-0.03944911297852475, 2692),
#  'cho chang': (0.08533399470899473, 2685),
#  'police': (-0.07428571428571427, 2682),
#  'roger davies': (-0.01738505747126437, 2680),
#  'mafalda': (0.24841591591591589, 2648),
#  'sports': (0.1925861606094164, 2622),
#  'arcus': (0.10437500000000002, 2620),
#  'revor': (-0.1013454861111111, 2620),
#  'leanne': (0.014502164502164495, 2617),
#  'blood traitor': (-0.16550520833333332, 2612),
#  'magorian': (0.014536830357142847, 2610),
#  'nicolas flamel': (0.18986013986013986, 2607),
#  'sword of gryffindor': (0.007788341416813628, 2590),
#  'anthony goldstein': (0.17505952380952386, 2578),
#  'colin creevey': (-0.007168458781362011, 2569),
#  'justin finch-fletchley': (0.05566502463054188, 2504),
#  'bloody baron': (-0.24794865565273733, 2497),
#  'hokey': (0.18542592592592597, 2493),
#  'bertha jorkins': (0.04546737213403881, 2492),
#  'devil': (-0.011903409090909084, 2456),
#  'muggle ar': (0.1463901689708141, 2451),
#  'erry boo': (0.07956349206349204, 2402),
#  'harper': (-0.006708900855242332, 2366),
#  'mary': (0.1906779529993816, 2323),
#  'bogrod': (0.0065303657694962, 2273),
#  'remus lupin': (0.1076984126984127, 2270),
#  'animagus': (-0.1296497584541063, 2233),
#  'ronan': (0.07083333333333333, 2205),
#  'horace slughorn': (-0.06763285024154589, 2204),
#  'cadogan': (0.015396825396825402, 2203),
#  'vernon dursley': (-0.002480158730158724, 2191),
#  'half-breed': (-0.09423500881834218, 2186),
#  'adrian pucey': (0.1391941391941392, 2153),
#  'adrian': (0.1391941391941392, 2153),
#  'bem': (0.026293103448275852, 2070),
#  'marcus flin': (0.16440746753246754, 2017),
#  'bletchley': (0.13157894736842107, 1992),
#  'dennis creevey': (0.08189097608740467, 1991),
#  'karkus': (0.01388463718820862, 1916),
#  'edgecombe': (0.07708333333333331, 1898),
#  'salazar slytherin': (0.1808823529411765, 1883),
#  'fortress': (0.12009523809523813, 1866),
#  'blackthorn wand': (0.025163398692810455, 1865),
#  'padma patil': (0.077415873015873, 1825),
#  'filibuster': (0.07437409812409812, 1818),
#  'miranda goshawk': (0.19004820936639122, 1790),
#  'moran': (-0.12967836257309942, 1742),
#  'romilda vane': (0.12745098039215685, 1701),
#  'runcorn': (0.1350799663299663, 1695),
#  'alber': (0.25379720853858784, 1687),
#  'godric gryffindor': (0.11249999999999999, 1678),
#  'sinistra': (0.026875000000000003, 1665),
#  'spindle': (-0.05820578231292516, 1645),
#  'inferius': (-0.03145833333333334, 1640),
#  'rubeus hagrid': (0.152536231884058, 1615),
#  'alice': (-0.019711934156378622, 1611),
#  'beedle the bard': (0.00019841269841268846, 1598),
#  'cole': (0.04836309523809521, 1559),
#  'mulle': (-0.10414332399626518, 1541),
#  'peter pettigrew': (-0.1322222222222222, 1540),
#  'security troll': (-0.08797097963764632, 1508),
#  'inde': (0.054204365079365074, 1502),
#  'millicent bulstrode': (-0.12987012987012986, 1487),
#  'scabior': (0.08980379188712523, 1474),
#  'urner': (-0.08906249999999999, 1470),
#  'glossy': (0.08415873015873016, 1461),
#  "devil's snare": (0.11250000000000003, 1459),
#  'he toad': (-0.022848788638262327, 1437),
#  'drooble': (0.317295386904762, 1418),
#  'mason': (-0.010784313725490198, 1361),
#  'snargaluff': (0.07486359126984127, 1357),
#  'arnold': (0.018951048951048946, 1354),
#  'alys': (0.2720238095238095, 1347),
#  'golgomath': (-0.002727272727272717, 1333),
#  'roberts': (-0.06753968253968254, 1301),
#  'amos diggory': (-0.08010204081632653, 1270),
#  'gellert grindelwald': (-0.05287037037037037, 1249),
#  'susan bones': (-0.10909090909090909, 1249),
#  'winkle': (0.09742063492063492, 1249),
#  'dedalus diggle': (0.0718452380952381, 1230),
#  'half-gian': (0.06130952380952382, 1217),
#  'dirk cresswell': (0.12281746031746028, 1214),
#  'ronald weasley': (0.11127450980392156, 1207),
#  'adalbert waffling': (0.2579166666666667, 1204),
#  'flurry': (0.03833333333333334, 1202),
#  'ofty': (0.07604166666666666, 1173),
#  'sturgis podmore': (0.18214285714285713, 1138),
#  'armando dippe': (-0.06911764705882353, 1134),
#  'queen': (-0.07708333333333332, 1133),
#  'cormac mclaggen': (0.19389880952380953, 1103),
#  'florean fortescue': (0.23782051282051284, 1096),
#  'patrick': (0.08863636363636368, 1091),
#  'elphias doge': (0.0858058608058608, 1090),
#  'spellman': (-0.06722222222222224, 1082),
#  'wilbert slinkhard': (0.23597081930415265, 1063),
#  'enophilius lovegood': (0.012424242424242426, 1047),
#  'everard': (0.20050264550264554, 1042),
#  'hepzibah smith': (0.12154040404040405, 1039),
#  'friar': (-0.010832281144781158, 1037),
#  'marvolo gaun': (-0.16946022727272725, 1027),
#  'sphin': (0.05298611111111109, 1025),
#  'lima': (0.034375, 1006),
#  'wandless': (0.02016975308641976, 993),
#  'gornuk': (0.1435185185185185, 991),
#  'quidditch captain': (0.11041666666666665, 988),
#  'demelza robins': (0.11859066859066861, 965),
#  'cadwallader': (0.1173611111111111, 943),
#  'father christmas': (0.21838474025974028, 942),
#  'good news': (0.3490740740740741, 926),
#  'puddifoo': (0.2506944444444445, 919),
#  'arsenius jigger': (0.21602564102564104, 914),
#  'phyllida spore': (0.21602564102564104, 914),
#  'quentin trimble': (0.21602564102564104, 914),
#  'mrs norris': (-0.18686868686868688, 913),
#  'nymphadora tonks': (0.1765873015873016, 910),
#  'executioner': (-0.06313131313131314, 904),
#  'head of gryffindor house': (0.2767361111111111, 901),
#  'gwenog': (0.08035714285714285, 893),
#  'head of departmen': (0.1293269230769231, 887),
#  'griffin': (-0.026011904761904764, 886),
#  'golpalo': (0.1487012987012987, 883),
#  'dudley dursley': (0.11182900432900432, 874),
#  'stark': (0.0496031746031746, 868),
#  'headless hun': (0.06875, 866),
#  'dilys derwen': (-0.059467120181405896, 860),
#  'ufty': (-0.10206349206349209, 857),
#  'willy widdershins': (-0.13541666666666666, 853),
#  'shrunken head': (-0.12811791383219956, 852),
#  'nicholas de mimsy-porpington': (-0.016696428571428577, 842),
#  'jim': (0.10333333333333335, 837),
#  'sybill trelawney': (-0.029861111111111123, 821),
#  'mountain troll': (0.22803030303030303, 818),
#  'alastor moody': (0.21980158730158733, 816),
#  'ripper': (-0.1007936507936508, 809),
#  'nash': (-0.06263888888888888, 804),
#  'fat friar': (0.0014898989898989635, 801),
#  'barnabas the barmy': (0.025, 776),
#  'gibbon': (0.12623456790123455, 776),
#  'bad news': (-0.23441176470588226, 774),
#  'stunned death eater': (0.13333333333333333, 760),
#  'mafalda hopkirk': (0.42135416666666664, 752),
#  'minerva mcgonagall': (0.04722222222222223, 749),
#  'emmeline vance': (0.060238095238095236, 744),
#  'young woman': (0.13125, 744),
#  'grumble': (0.13645276292335115, 739),
#  'rosie': (-0.05080357142857143, 733),
#  'frank bryce': (-0.00879629629629629, 729),
#  'opposition': (0.07166666666666666, 725),
#  'luke': (-0.03920454545454546, 712),
#  'bertie bo': (0.23333333333333334, 707),
#  'dragon keeper': (0.3225, 707),
#  'gwenog jones': (0.1527777777777778, 706),
#  'hermes': (0.06888888888888889, 693),
#  'om riddle senior': (0.0004861111111111131, 691),
#  'caractacus burke': (0.1619047619047619, 688),
#  'caractacus': (0.1619047619047619, 688),
#  'bas': (0.12261904761904763, 677),
#  'charity burbage': (-0.06984126984126984, 668),
#  'bilius': (0.010714285714285704, 659),
#  'selwyn': (-0.04878968253968254, 630),
#  'fitness': (0.13666666666666666, 628),
#  'apparition instructor': (0.06833333333333334, 609),
#  'narcissa malfoy': (0.12777777777777777, 609),
#  'pius thicknesse': (0.2590909090909091, 603),
#  'brutus': (0.04285714285714286, 602),
#  'he monster book of monsters': (0.020535714285714282, 599),
#  'kendra dumbledore': (-0.03159722222222222, 592),
#  'barnabus finkley': (0.2074074074074074, 590),
#  'helga hufflepuff': (0.07083333333333333, 590),
#  'fenrir greyback': (0.11888888888888889, 587),
#  'celestina warbeck': (0.29, 586),
#  'stubby boardman': (0.0636904761904762, 579),
#  'fountain of magical brethren': (0.18250000000000002, 578),
#  'libatius borage': (0.32, 572),
#  'acromantula': (-0.12447916666666665, 564),
#  'hestia jones': (0.25, 564),
#  'ivor dillonsby': (-0.07166666666666667, 563),
#  'euan abercrombie': (0.054907407407407405, 558),
#  'non-magic people': (0.1264324960753532, 553),
#  'amelia bones': (0.28611111111111115, 552),
#  'eileen prince': (0.2142857142857143, 540),
#  'hassan mostafa': (-0.03333333333333334, 540),
#  'alecto carrow': (-0.05333333333333332, 539),
#  'arabella figg': (-0.07500000000000001, 538),
#  'suit of armour': (-0.1763392857142857, 537),
#  'portly ghos': (0.17346938775510204, 536),
#  'vincent crabbe': (-0.07283950617283949, 529),
#  'aged witch': (-0.0666666666666667, 526),
#  'gregory the smarmy': (0.015123966942148752, 520),
#  'rio': (0.25520833333333337, 518),
#  'serpent of slytherin': (-0.21666666666666667, 512),
#  'oswald': (0.34809523809523807, 504),
#  'bob ogden': (0.26111111111111107, 499),
#  'baruffio': (0.08925925925925925, 497),
#  'dexter fortescue': (-0.14513888888888887, 494),
#  'gregory goyle': (-0.1479166666666667, 492),
#  'antonin dolohov': (-0.1695833333333333, 482),
#  'scarpin': (0.2340909090909091, 480),
#  'binky': (-0.02291666666666667, 475),
#  'jimmy peakes': (0.1, 475),
#  'barry ryan': (0.1175925925925926, 474),
#  'poppy': (-0.006388888888888888, 470),
#  'wilkie twycross': (-0.031428571428571424, 470),
#  'chambers': (0.03555555555555555, 467),
#  'iberius': (0.5666666666666667, 462),
#  'griselda marchbanks': (0.09166666666666666, 461),
#  'jugson': (0.12261904761904763, 458),
#  'penelope clearwater': (0.3333333333333333, 458),
#  'pierre bonaccord': (0.05, 458),
#  'enid smeek': (-0.07638888888888891, 449),
#  'catchpole': (0.0640625, 448),
#  'malcolm': (-0.3201388888888889, 435),
#  'scrivenshaf': (0.03166666666666667, 435),
#  'bodrod the bearded': (0.08166666666666665, 432),
#  'urg the unclean': (0.08166666666666665, 432),
#  'rowena ravenclaw': (0.15833333333333333, 430),
#  'harold dingle': (-0.05, 429),
#  'amy benson': (-0.04538690476190477, 428),
#  'dennis bishop': (-0.04538690476190477, 428),
#  'eloise midgen': (0.028571428571428564, 427),
#  'urquhar': (0.0327020202020202, 423),
#  'phineas nigellus black': (-0.08333333333333333, 418),
#  'dentis': (0.545, 417),
#  'miles bletchley': (-0.16666666666666666, 408),
#  'junior minister': (0.27083333333333337, 406),
#  'fabian prewe': (-0.2657142857142857, 405),
#  'potioneer': (0.2619047619047619, 404),
#  'jack sloper': (0.024999999999999994, 399),
#  'heather': (-0.0919642857142857, 397),
#  'stanley shunpike': (0.25, 391),
#  'summers': (0.46249999999999997, 389),
#  'sunday prophe': (0.10000000000000002, 389),
#  'frank longbottom': (0.0, 388),
#  'dougal': (0.140625, 377),
#  'gossamer': (-0.30000000000000004, 377),
#  'morag': (0.140625, 377),
#  'eldred worple': (-0.2, 371),
#  'secret keeper': (-0.05, 371),
#  'billy stubbs': (-0.03333333333333333, 370),
#  'ubbs': (-0.03333333333333333, 370),
#  'ignotus peverell': (0.19147727272727275, 369),
#  'molly weasley': (0.12, 366),
#  'kevin': (0.15157407407407406, 365),
#  'stewar': (-0.15555555555555559, 359),
#  "hufflepuff's cup": (-0.05, 356),
#  'regulus black': (-0.033333333333333326, 355),
#  'peverell brothers': (0.11666666666666665, 354),
#  'ragnok': (0.049999999999999996, 353),
#  'marietta edgecombe': (-0.06285714285714286, 348),
#  'sirius black i': (-0.027604166666666676, 348),
#  'eric whalley': (-0.03333333333333333, 346),
#  'summerby': (-0.044920634920634916, 342),
#  'fawce': (0.037500000000000006, 340),
#  'glen': (0.21321969696969698, 338),
#  'ritchie coote': (0.15, 338),
#  'metamorphmagus': (-0.1, 337),
#  'miriam strou': (-0.125, 337),
#  'obias snape': (0.03333333333333333, 329),
#  'evening prophe': (0.0, 327),
#  'cassandra vablatsky': (-0.038888888888888896, 326),
#  'heodore no': (0.32499999999999996, 325),
#  'ariana dumbledore': (0.05555555555555555, 324),
#  'roupe of dancing skeletons': (0.24294990723562152, 324),
#  'gang of slytherins': (-0.0533333333333333, 323),
#  'doris crockford': (0.009999999999999998, 322),
#  'hogwarts house-elves': (0.75, 318),
#  'alderton': (0.019999999999999997, 316),
#  'arkie alderton': (0.019999999999999997, 316),
#  'vaisey': (0.5, 315),
#  'boris the bewildered': (0.017142857142857137, 310),
#  'fallen fifty': (0.06999999999999999, 309),
#  'gamp': (0.10000000000000002, 309),
#  'art historian': (0.0, 308),
#  'chancellor of the exchequer': (0.0, 308),
#  'herbert chorley': (0.5, 307),
#  'eddie carmichael': (0.07222222222222223, 291),
#  'heoretician': (0.33571428571428574, 290),
#  'olive hornby': (-0.16666666666666666, 283),
#  'dai llewellyn': (-0.01598639455782313, 282),
#  'hans': (0.303125, 281),
#  'venomous tentacula': (-0.08571428571428572, 280),
#  'lachlan the lanky': (-0.3299107142857143, 279),
#  'rick wand': (-0.037500000000000006, 278),
#  'brian': (-0.05, 277),
#  'ali bashir': (0.34375, 273),
#  'heady': (0.0, 272),
#  'fridwulfa': (-0.014999999999999996, 269),
#  'rodolphus lestrange': (-0.05555555555555555, 267),
#  'elfric the eager': (-0.018518518518518535, 266),
#  'williamson': (0.0, 266),
#  'committee on experimental charms': (0.011111111111111118, 260),
#  'gigantic serpen': (-0.16799999999999998, 259),
#  'proudfoo': (0.08714285714285715, 257),
#  'warty harris': (-0.13303571428571428, 256),
#  'astronomy departmen': (0.1, 255),
#  'daily prophet grand prize galleon draw': (0.4, 254),
#  'gideon prewe': (0.0, 251),
#  'alice longbottom': (-0.031249999999999986, 250),
#  'augusta longbottom': (0.47142857142857136, 249),
#  'bungy': (0.1125, 243),
#  'agnes': (0.23000000000000004, 241),
#  'janus thickey': (-0.1, 239),
#  'bowman wrigh': (0.35000000000000003, 237),
#  'walden macnair': (0.0, 237),
#  'hogwartian': (-0.06000000000000001, 232),
#  'vindictus viridian': (0.3, 232),
#  'joey jenkins': (0.0, 230),
#  'bertie higgs': (-0.125, 229),
#  'senior undersecretary to the minister for magic': (0.425, 227),
#  'eagle door knocker': (0.11499999999999999, 226),
#  'morfin gaun': (0.09999999999999998, 225),
#  'wendelin the weird': (-0.036111111111111115, 222),
#  'helena ravenclaw': (-0.21428571428571427, 221),
#  'james potter i': (-0.18333333333333335, 217),
#  'black knigh': (-0.16666666666666666, 216),
#  'curse-breaker': (0.125, 216),
#  'fleetwood': (0.054761904761904755, 216),
#  'piers polkiss': (0.625, 215),
#  'benjy fenwick': (0.0, 213),
#  'maiden': (-0.28, 213),
#  'stewart ackerley': (-0.15555555555555559, 212),
#  'forecas': (-0.05, 211),
#  'wealthy man who owned the riddle house': (0.315, 207),
#  'mills': (-0.12883838383838384, 206),
#  'head of slytherin house': (0.475, 205),
#  'veronica smethley': (0.30714285714285716, 205),
#  'wizarding wireless network news': (0.13333333333333333, 204),
#  'charlie g': (-0.18472222222222223, 202),
#  "riddles' cook": (0.0, 201),
#  'court scribe': (-0.06666666666666667, 200),
#  'he fates': (-0.25, 200),
#  'wo little witches': (0.10559523809523809, 199),
#  'bradley': (0.15625, 198),
#  'blaise zabini': (-0.125, 196),
#  'gordon': (-0.3333333333333333, 193),
#  'self-spelling wand': (0.14444444444444446, 191),
#  'bozo': (0.23333333333333336, 190),
#  'geoffrey hooper': (0.19166666666666665, 189),
#  'registry': (0.0, 189),
#  'vicky frobisher': (0.19166666666666665, 189),
#  'urquhart rackharrow': (0.0, 188),
#  'montgomery sisters': (0.4708333333333334, 186),
#  'montgomery': (0.4708333333333334, 186),
#  'gloomy nuns': (0.4, 185),
#  'knight with an arrow sticking out of his forehead': (0.4, 185),
#  'elfrida cragg': (0.5249999999999999, 184),
#  'martin miggs': (-0.3125, 184),
#  'jay': (0.19999999999999998, 183),
#  'matey': (-0.05, 182),
#  'assassin': (-0.1703125, 181),
#  'murcus': (0.25, 181),
#  'bandon banshee': (0.08124999999999999, 179),
#  'marius': (-0.18888888888888888, 176),
#  'african prince': (0.25, 173),
#  'magick moste evile': (0.5, 173),
#  'zoo director': (0.3916666666666666, 172),
#  'humphrey belcher': (-0.10714285714285715, 171),
#  "roger davies's girlfriend": (-0.303125, 170),
#  'eric munch': (0.5, 167),
#  'alking mirror': (0.35, 166),
#  'ambrosius flume': (0.40625, 165),
#  'ciceron harkiss': (0.40625, 165),
#  'igor karkaroff': (0.05, 165),
#  "international confederation of wizards' conference": (-0.5, 165),
#  'aberforth dumbledore': (0.25625, 164),
#  'fubster': (-0.041666666666666664, 163),
#  'wild boar': (0.03333333333333333, 163),
#  'connolly': (-0.3, 162),
#  'loxias': (-0.3333333333333333, 162),
#  'skower': (0.27, 162),
#  'quidditch referee': (-0.325, 161),
#  'cassandra trelawney': (0.13749999999999998, 157),
#  "draco malfoy's eagle owl": (-0.1875, 157),
#  'mary macdonald': (-0.2625, 157),
#  'melinda bobbin': (0.10416666666666664, 157),
#  'florence': (-0.1, 156),
#  "marvolo gaunt's ring": (-0.09375, 156),
#  'pringle': (0.0, 156),
#  'squire': (0.0, 156),
#  'bernie': (-0.3, 152),
#  'he hopping po': (0.32499999999999996, 152),
#  'dragomir gorgovitch': (0.5, 151),
#  'he invisible book of invisibility': (-1.0, 147),
#  'gawain robards': (0.0, 142),
#  'galatea merrythough': (0.1, 138),
#  'cliodna': (0.0, 137),
#  'fisher': (0.0, 136),
#  'ptolemy': (0.0, 129),
#  'shrieking book': (-0.051851851851851864, 128),
#  "pansy parkinson's gang": (0.0, 127),
#  'gladys gudgeon': (0.32500000000000007, 126),
#  'octavius pepper': (0.0, 126),
#  'laura': (0.3416666666666666, 124),
#  'picture of drunk monks': (-0.3277777777777778, 124),
#  'millicent bagnold': (0.0, 121),
#  'uric the oddball': (-0.38518518518518524, 121),
#  'abraxas malfoy': (0.0, 120),
#  'alberic grunnion': (0.0, 120),
#  'circe': (0.0, 120),
#  'hector dagworth-granger': (0.27777777777777773, 120),
#  'hengist of woodcrof': (0.0, 120),
#  'most extraordinary society of potioneers': (0.27777777777777773, 120),
#  'doris purkiss': (-0.11805555555555554, 118),
#  'barnabas cuffe': (0.125, 117),
#  'hippocrates smethwyck': (0.0, 117),
#  'marcus belby': (-0.05000000000000002, 117),
#  'gilbert wimple': (0.1, 115),
#  'egbert the egregious': (-0.25, 114),
#  'emeric the evil': (-0.25, 114),
#  'horfinn rowle': (-0.3958333333333333, 114),
#  'wilfred the wistful': (-0.2, 112),
#  'patrick delaney-podmore': (0.55, 110),
#  'poliakoff': (0.3, 110),
#  'emma dobbs': (-0.3791666666666667, 108),
#  'merope riddle': (-0.2, 107),
#  'mosag': (0.0, 107),
#  'armenian warlock': (-0.1333333333333333, 106),
#  'head of hufflepuff house': (-0.1, 105),
#  'marjorie dursley': (0.0, 105),
#  'ludovic bagman': (0.0, 104),
#  'yvonne': (0.0, 103),
#  'petunia dursley': (0.0, 102),
#  'gable': (0.16, 101),
#  'hogwarts gobstones team': (0.0, 99),
#  'marlene mckinnon': (0.0, 99),
#  'wakanda': (-0.6, 99),
#  'augustus pye': (0.0, 96),
#  'davey gudgeon': (0.1, 96),
#  'augustus rookwood': (0.0, 95),
#  'daphne greengrass': (0.0, 92),
#  'mark evans': (0.0, 89),
#  'godelo': (0.6, 88),
#  'hereward': (0.6, 88),
#  'wilkes': (-0.2, 85),
#  'inigo imago': (0.0, 84),
#  'norberta': (0.0, 84),
#  'albino peacock': (0.0, 83),
#  'kenneth towler': (0.0, 83),
#  "slytherin's locke": (0.0, 82),
#  'reginald cattermole': (0.375, 80),
#  'zoological column': (0.5, 78),
#  'caradoc dearborn': (0.0, 76),
#  'fergus': (0.0, 76),
#  'quidditch commentator': (0.13636363636363635, 76),
#  'ragnuk': (0.3125, 73),
#  'wagga wagga werewolf': (0.0, 72),
#  'american plumbers': (0.1625, 70),
#  'greengrocer': (0.7, 68),
#  'andrew kirke': (0.0, 66),
#  'andrew': (0.0, 66),
#  'keeper of the reptile house': (0.0, 66),
#  'mary dorkins': (0.5, 64),
#  'veela hair': (0.0, 64),
#  'dorcas meadowes': (-0.1, 58),
#  'alfred cattermole': (0.0, 55),
#  'magician': (0.0, 55),
#  'malcolm baddock': (-0.15555555555555559, 55),
#  'bertram aubrey': (-0.5, 54),
#  'eliza': (0.0, 53),
#  'wailing widow': (0.0, 50),
#  'hetty bayliss': (0.0, 49),
#  'erence higgs': (0.0, 49),
#  'angus flee': (0.0, 48),
#  'angus': (0.0, 48),
#  'evan rosier': (-0.2, 48),
#  'jim mcguffin': (0.0, 48),
#  'broderick bode': (0.0, 46),
#  'livius': (-0.6, 43),
#  'mary cattermole': (0.0, 43),
#  'patricia stimpson': (-0.5, 43),
#  'hebridean black': (-0.25, 42),
#  'dobbin': (0.0, 41),
#  'cecilia': (0.0, 36),
#  'payne': (0.2, 36),
#  'prentice': (0.0, 28),
#  "billy stubbs's rabbi": (0.0, 24),
#  'edgar bones': (0.0, 22),
#  'edgar': (0.0, 22),
#  'avery i': (0.0, 14)}

# %% [markdown]
# word2vec

# %%
# catch all the texts into a 2d list for later training
from os import listdir
import nltk
from nltk.corpus import stopwords


def clean_text(doc):
    doc = doc.strip('.txt')
    doc = doc+'.txt'
    ws = open(data_dir + doc, 'r', encoding='UTF-8').read()
    ws = ws.translate(str.maketrans('', '', '"#$%&\()*+,-/:;<=>@[\\]^_`{|}~.!?')) # remove punctuations               
    ws = nltk.word_tokenize(ws)  
    ws = [w.lower() for w in ws if not w in stopwords.words('english')] 
    return ws

data_dir = "./data/"
docLabels = [f for f in listdir(data_dir) if f.endswith('.txt')]
data = []
for doc in docLabels:
    data.append(clean_text(doc))
print(len(data))

# %%
from gensim.corpora import Dictionary
from gensim.models import TfidfModel
from gensim.similarities import SparseMatrixSimilarity

word_dictionary = Dictionary(data)
num_featureword_dictionarys = len(word_dictionary.token2id)
# based on the dict we got, transfer the word_vec to be corpus sets
corpus = [word_dictionary.doc2bow(text) for text in data]
# build the tf-idf model, then input it  into the corpus sets for training
tfidf = TfidfModel(corpus)
# to handle the text by the usage of tf-idf model
tf_texts = tfidf[corpus] 
# build the similiarity matrix which will be used for caculating simularities between  characters
sparse_matrix = SparseMatrixSimilarity(tf_texts, num_features)

# %%
def clean_text_2(text):
    ws =text.translate(str.maketrans('', '', '"#$%&\()*+,-/:;<=>@[\\]^_`{|}~.!?')) # remove punctuations               
    ws = nltk.word_tokenize(ws)  
    ws = [w.lower() for w in ws if not w in stopwords.words('english')] 
    return ws

def caculate_similarity(character,isOwntxt = 0): # is your own input text or not
    if isOwntxt == 0:
        keywords = clean_text(character)
    else:
        keywords = clean_text_2(character)
    kw_vector = word_dictionary.doc2bow(keywords)
    tf_kw = tfidf[kw_vector]
    similarities = sparse_matrix.get_similarities(tf_kw)
    similarity_dict = {}
    for e, s in enumerate(similarities, 1):
        name = docLabels[e-1].strip('.txt')
        similarity_dict[name] = s
        
    similarity_dict= dict(sorted(similarity_dict.items(), key=lambda item:item[1], reverse = True))
    return similarity_dict

def one2one_similarity(character_1,character_2,isOwntxt = 0): # input two character names, or one of your own text and another character
    if isOwntxt == 0:
        keywords = clean_text(character_2)
    else:
        keywords = clean_text_2(character_2)
        
    kw_vector = word_dictionary.doc2bow(keywords)
    tf_kw = tfidf[kw_vector]
    similarities = sparse_matrix.get_similarities(tf_kw)
    similarity_dict = {}
    for e, s in enumerate(similarities, 1):
        name = docLabels[e-1].strip('.txt')
        similarity_dict[name] = s
        
    return similarity_dict[character_1.strip('.txt')]

# %%
caculate_similarity('harry potter')
# Out:
# {'harry potter': 0.9999966,
#  'harry potter ': 0.5341101,
#  'dobby': 0.5155143,
#  'will': 0.39360312,
#  'ed': 0.33855754,
#  'ar': 0.32212874,
#  'red': 0.31368235,
#  'ned': 0.2949499,
#  'king': 0.291786,
#  'im': 0.22983325,
#  'name': 0.22486505,
#  'coun': 0.21103942,
#  'dan': 0.20935975,
#  'om': 0.20627074,
#  'goblet of fire': 0.1977547,
#  'house-elf': 0.1976297,
#  'winky': 0.1876138,
#  'seer': 0.18513665,
#  'hall': 0.18190208,
#  'bell': 0.17604175,
#  'mark': 0.16573286,
#  'wand': 0.16410077,
#  'follo': 0.16386934,
#  'lima': 0.15841037,
#  'muggle-born': 0.15470488,
#  'horace': 0.15340182,
#  'horace slughorn': 0.14958723,
#  'professor': 0.1471052,
#  'kreacher': 0.14591844,
#  'augusta longbottom': 0.14343353,
#  'aberforth dumbledore': 0.14309534,
#  'roll': 0.1421874,
#  'horcru': 0.14177178,
#  'mina': 0.13938522,
#  'roy': 0.13628224,
#  'james potter i': 0.13551486,
#  'hogwarts house-elves': 0.13503367,
#  'minister': 0.13177554,
#  'god': 0.12481705,
#  'asha': 0.121489145,
#  'hermione granger': 0.12056968,
#  'auror': 0.1199159,
#  'half-blood': 0.11883193,
#  'prince': 0.11870028,
#  'dirk': 0.118410625,
#  'chas': 0.114138395,
#  'do': 0.11265839,
#  'luna lovegood': 0.11244741,
#  'griphook': 0.11211983,
#  'albus dumbledore': 0.11116225,
#  'lion': 0.10667189,
#  'sirius black': 0.104142725,
#  'enophilius lovegood': 0.103238426,
#  'dementor': 0.102981254,
#  'sword of gryffindor': 0.102313496,
#  'bush': 0.10189948,
#  'gian': 0.100662254,
#  'draco malfoy': 0.09929742,
#  'savage': 0.09823686,
#  'minerva': 0.09809983,
#  'snake': 0.09726603,
#  'arthur weasley': 0.09451795,
#  'eagle': 0.09392693,
#  'prime minister': 0.09269952,
#  'jack': 0.09220934,
#  'rita skeeter': 0.091912694,
#  'angel': 0.091079295,
#  'bogrod': 0.09053052,
#  'dark mark': 0.090067565,
#  'no': 0.09001012,
#  'jugson': 0.08987673,
#  'rubeus hagrid': 0.08931834,
#  'michael': 0.08838251,
#  'u': 0.08805854,
#  'merlin': 0.08681831,
#  'bas': 0.08622318,
#  'arthur': 0.08525751,
#  'health': 0.08525231,
#  'muriel': 0.08467262,
#  'selwyn': 0.08462088,
#  'lucius malfoy': 0.08381641,
#  'werewolf': 0.08379186,
#  'severus snape': 0.08296626,
#  'centaur': 0.08192593,
#  'commen': 0.081527,
#  'abbo': 0.08126547,
#  'zonko': 0.081195824,
#  'runcorn': 0.081105575,
#  'young woman': 0.08083082,
#  'george weasley': 0.08067322,
#  'hestral': 0.080516964,
#  'fred and george weasley': 0.08049959,
#  'lestrange': 0.08004664,
#  'squib': 0.07973566,
#  'michael corner': 0.07960428,
#  'dolores umbridge': 0.07909631,
#  'mafalda': 0.079053596,
#  'goyle': 0.07871002,
#  'portrai': 0.078094326,
#  'brown': 0.077642165,
#  'dragon keeper': 0.07756065,
#  'salazar slytherin': 0.076960325,
#  'cadogan': 0.07664215,
#  'wool': 0.076075904,
#  'fred weasley': 0.07542207,
#  'fawkes': 0.07527812,
#  'lee jordan': 0.07519207,
#  'hedwig': 0.075017095,
#  'basil': 0.07402577,
#  'minerva mcgonagall': 0.07369587,
#  'dudley': 0.073580444,
#  'ubbly': 0.0734371,
#  'hannah abbo': 0.07308919,
#  'bob': 0.07295369,
#  'blood traitor': 0.07213047,
#  'crabbe': 0.07140181,
#  'firenze': 0.069789186,
#  'fang': 0.069435276,
#  'alber': 0.06926147,
#  'wandmaker': 0.06912138,
#  'bagsho': 0.069000326,
#  'gringo': 0.06896508,
#  'badger': 0.068740435,
#  'erry boo': 0.06868558,
#  'viole': 0.06824601,
#  'bellatrix lestrange': 0.06775471,
#  'muggle ar': 0.06741574,
#  'games': 0.06731865,
#  'nigel': 0.06722661,
#  'willy widdershins': 0.066655464,
#  'opinion': 0.066253714,
#  'om riddle': 0.06618672,
#  'peeves': 0.0658678,
#  'bathilda bagsho': 0.06583917,
#  'mandrake': 0.06580988,
#  'pike': 0.065577924,
#  'frank': 0.06515134,
#  'mary': 0.06484332,
#  'dirk cresswell': 0.06421323,
#  'katie bell': 0.06391563,
#  'oliver wood': 0.063797586,
#  'malkin': 0.06360874,
#  'international': 0.063036725,
#  'good news': 0.062926374,
#  'neville longbottom': 0.06292369,
#  'anthony goldstein': 0.062733255,
#  'inferius': 0.06271901,
#  'finch': 0.06244314,
#  'john': 0.062383853,
#  'grawp': 0.06199045,
#  'mundungus fletcher': 0.06190398,
#  'cedric': 0.061324168,
#  'lavender brown': 0.061010044,
#  'inde': 0.060359962,
#  'patrick': 0.059998754,
#  'urner': 0.059867002,
#  'pure-blood': 0.058895428,
#  'sorting ha': 0.05880994,
#  'gargoyle': 0.05803919,
#  'zacharias smith': 0.05782596,
#  'bean': 0.057705794,
#  'healer': 0.057167213,
#  'luke': 0.05706283,
#  'half-breed': 0.05634058,
#  'percy weasley': 0.05621772,
#  'bem': 0.056171797,
#  'knigh': 0.055932824,
#  'horfinn rowle': 0.055708736,
#  'gibbon': 0.054968223,
#  'kingsley shacklebol': 0.054959964,
#  'alicia spinne': 0.05472645,
#  'harper': 0.05453295,
#  'marvolo gaun': 0.054503374,
#  'armando dippe': 0.05448456,
#  'head of departmen': 0.05418368,
#  'fluffy': 0.05392186,
#  'scabior': 0.05389628,
#  'bane': 0.053712334,
#  'abraxas malfoy': 0.053534057,
#  "hufflepuff's cup": 0.053514272,
#  'vernon dursley': 0.053362343,
#  'buckbeak': 0.05320268,
#  'gornuk': 0.05234689,
#  'ofty': 0.052300196,
#  'justin finch-fletchley': 0.052242357,
#  'bernie': 0.052017268,
#  'marsh': 0.05191087,
#  'hepzibah smith': 0.05160951,
#  'cornelius fudge': 0.051581267,
#  'ravers': 0.051209837,
#  'dedalus diggle': 0.051178366,
#  "marauder's map": 0.051127303,
#  'colin creevey': 0.051040713,
#  'alderton': 0.050918594,
#  'arkie alderton': 0.050918594,
#  'pius thicknesse': 0.050676502,
#  'spellman': 0.050559256,
#  'snargaluff': 0.050147075,
#  'headless hun': 0.049975757,
#  'crookshanks': 0.04997263,
#  'ugga': 0.049934767,
#  'finn': 0.049879033,
#  'stark': 0.049513277,
#  'gregory the smarmy': 0.049468875,
#  'brutus': 0.049272504,
#  'unicorn': 0.048926763,
#  'nagini': 0.048579317,
#  'wizarding wireless network news': 0.048563074,
#  'quidditch captain': 0.04776892,
#  'shrunken head': 0.047574107,
#  'everard': 0.04750946,
#  'devil': 0.047256943,
#  'dennis': 0.047140274,
#  'stunned death eater': 0.047139715,
#  'eagle door knocker': 0.04687403,
#  'godric gryffindor': 0.04683486,
#  'fortress': 0.046508428,
#  'parseltongue': 0.046507392,
#  'he toad': 0.046328768,
#  'dennis creevey': 0.04632003,
#  'adrian pucey': 0.046107315,
#  'adrian': 0.046107315,
#  'alys': 0.045920487,
#  'parvati patil': 0.04579481,
#  'ufty': 0.04551113,
#  'barnabas the barmy': 0.045426473,
#  'wakanda': 0.04517958,
#  'padma patil': 0.044971798,
#  'aged witch': 0.044954088,
#  'bodrod the bearded': 0.044807684,
#  'urg the unclean': 0.044807684,
#  'rosmerta': 0.04457668,
#  'head of hufflepuff house': 0.044159595,
#  'remus lupin': 0.043913707,
#  'kendra dumbledore': 0.04351488,
#  'aragog': 0.043168128,
#  'security troll': 0.042985253,
#  'queen': 0.042840198,
#  'seamus finnigan': 0.042519253,
#  'enid smeek': 0.042447012,
#  'snowy': 0.042421684,
#  'nicolas flamel': 0.042374883,
#  'pansy parkinson': 0.0421312,
#  'quidditch referee': 0.041970786,
#  'dean thomas': 0.04172402,
#  'blackthorn wand': 0.041309886,
#  'susan bones': 0.041295514,
#  'beedle the bard': 0.040840264,
#  'barnabus finkley': 0.040829916,
#  'borgin': 0.040804625,
#  'puddifoo': 0.040380403,
#  'hokey': 0.040367927,
#  'cedric diggory': 0.040272914,
#  'bilius': 0.040210005,
#  'mary cattermole': 0.040089875,
#  'secret keeper': 0.039969582,
#  'opposition': 0.03993107,
#  'sinistra': 0.039661184,
#  'molly weasley': 0.03952412,
#  'libatius borage': 0.039419737,
#  'arcus': 0.039405763,
#  'bad news': 0.039311074,
#  'ivor dillonsby': 0.03928519,
#  'karkus': 0.039178412,
#  'fat lady': 0.03896145,
#  'grumble': 0.038764194,
#  'revor': 0.03824053,
#  'leanne': 0.038072646,
#  'rio': 0.038035296,
#  'alking mirror': 0.037738863,
#  'marcus flin': 0.037704516,
#  'elphias doge': 0.037185095,
#  'angelina johnson': 0.037120987,
#  'errol': 0.036991604,
#  'obias snape': 0.036895804,
#  'peter': 0.03661804,
#  'rufus scrimgeour': 0.036406405,
#  'romilda vane': 0.03635512,
#  'bloody baron': 0.036345348,
#  'acromantula': 0.036312997,
#  'bletchley': 0.036231417,
#  'winkle': 0.03610249,
#  'non-magic people': 0.035974573,
#  'jim': 0.035878986,
#  'nicholas de mimsy-porpington': 0.0356648,
#  'animagus': 0.03561785,
#  'eldred worple': 0.03494279,
#  'magorian': 0.034918863,
#  'dilys derwen': 0.034848005,
#  'head of gryffindor house': 0.034847826,
#  'cho chang': 0.03480921,
#  'cassandra vablatsky': 0.034802534,
#  'leprechaun': 0.034574397,
#  'gilderoy lockhar': 0.03452949,
#  'fabian prewe': 0.03425896,
#  'om riddle senior': 0.034161724,
#  'wandless': 0.034118615,
#  'alice': 0.03397279,
#  'heady': 0.033716887,
#  'edgecombe': 0.03355537,
#  'gamp': 0.033551298,
#  'half-gian': 0.03341023,
#  'gang of slytherins': 0.033406634,
#  'sybill trelawney': 0.03337868,
#  'heodore no': 0.033304233,
#  'florence': 0.033295278,
#  'humphrey belcher': 0.033175845,
#  'joey jenkins': 0.03303426,
#  'poppy': 0.033010036,
#  'golgomath': 0.032783095,
#  'spindle': 0.03277776,
#  'caractacus burke': 0.032775875,
#  'caractacus': 0.032775875,
#  'antonin dolohov': 0.032616418,
#  'alastor moody': 0.032503277,
#  'amos diggory': 0.031919416,
#  'peter pettigrew': 0.03186202,
#  'eileen prince': 0.031690262,
#  'elfrida cragg': 0.031554446,
#  'sunday prophe': 0.031434137,
#  'montgomery sisters': 0.031088226,
#  'montgomery': 0.031088226,
#  'flurry': 0.031060837,
#  'scrivenshaf': 0.031059079,
#  'nash': 0.0309523,
#  'mountain troll': 0.03093094,
#  'bozo': 0.03084064,
#  'ronald weasley': 0.030720353,
#  'helga hufflepuff': 0.03071433,
#  'sports': 0.030708592,
#  'charity burbage': 0.030705076,
#  'dougal': 0.030570935,
#  'morag': 0.030570935,
#  'cormac mclaggen': 0.03044369,
#  'police': 0.030341998,
#  'rodolphus lestrange': 0.029996458,
#  'fleur delacour': 0.029965503,
#  'alice longbottom': 0.029958574,
#  'alecto carrow': 0.0298406,
#  'golpalo': 0.029772015,
#  'viktor krum': 0.029673811,
#  'chambers': 0.029361434,
#  'pringle': 0.029286081,
#  'roger davies': 0.029059494,
#  'cadwallader': 0.029006086,
#  'euan abercrombie': 0.028856225,
#  'mafalda hopkirk': 0.028729545,
#  'merope riddle': 0.028505074,
#  'argus filch': 0.028504893,
#  'filibuster': 0.02834606,
#  'ignotus peverell': 0.028295174,
#  'friar': 0.02815079,
#  'narcissa malfoy': 0.028093545,
#  'ronan': 0.028043156,
#  'jack sloper': 0.027940048,
#  'harold dingle': 0.027784571,
#  'mary dorkins': 0.027674379,
#  'nymphadora tonks': 0.02736037,
#  'arnold': 0.027133884,
#  'sphin': 0.027106363,
#  'frank longbottom': 0.02704616,
#  'metamorphmagus': 0.027006485,
#  'walden macnair': 0.026989343,
#  'stubby boardman': 0.026932944,
#  "devil's snare": 0.026926741,
#  'doris crockford': 0.026876686,
#  'demelza robins': 0.026870238,
#  'ludovic bagman': 0.026853105,
#  'oswald': 0.026827909,
#  'baruffio': 0.02677884,
#  'arsenius jigger': 0.026436651,
#  'phyllida spore': 0.026436651,
#  'quentin trimble': 0.026436651,
#  'stanley shunpike': 0.026387867,
#  'ariana dumbledore': 0.026363557,
#  'dentis': 0.026238015,
#  'mills': 0.02618699,
#  'patrick delaney-podmore': 0.025907604,
#  'ragnok': 0.025794048,
#  'eliza': 0.025746914,
#  'mrs norris': 0.025717389,
#  'dudley dursley': 0.025671002,
#  'phineas nigellus black': 0.025663178,
#  'adalbert waffling': 0.02562404,
#  'court scribe': 0.025582701,
#  'marietta edgecombe': 0.025411064,
#  'head of slytherin house': 0.025322404,
#  'millicent bagnold': 0.025315663,
#  'melinda bobbin': 0.025306825,
#  'portly ghos': 0.025125442,
#  'dexter fortescue': 0.02505938,
#  'warty harris': 0.024934648,
#  'jimmy peakes': 0.024882866,
#  'gellert grindelwald': 0.024681317,
#  'florean fortescue': 0.024635592,
#  'griffin': 0.02448231,
#  'mary macdonald': 0.024316859,
#  'rosie': 0.024314892,
#  'heather': 0.024181359,
#  'forecas': 0.024174584,
#  'gregory goyle': 0.02394219,
#  "draco malfoy's eagle owl": 0.02378375,
#  'fat friar': 0.023706349,
#  'hermes': 0.023689682,
#  'amy benson': 0.023362493,
#  'dennis bishop': 0.023362493,
#  'glossy': 0.023286534,
#  'veronica smethley': 0.023251394,
#  'wealthy man who owned the riddle house': 0.023194252,
#  'miranda goshawk': 0.023030953,
#  'mason': 0.023026984,
#  'ptolemy': 0.022937274,
#  'arabella figg': 0.022823876,
#  "marvolo gaunt's ring": 0.022777572,
#  'amelia bones': 0.022761961,
#  'brian': 0.022636894,
#  'piers polkiss': 0.022492876,
#  'peverell brothers': 0.022435699,
#  'charlie g': 0.021959033,
#  'bertha jorkins': 0.021950142,
#  'roupe of dancing skeletons': 0.021814944,
#  'rowena ravenclaw': 0.021727126,
#  'regulus black': 0.02171408,
#  'reginald cattermole': 0.021705495,
#  'barry ryan': 0.021626811,
#  'celestina warbeck': 0.02162521,
#  'black knigh': 0.021535587,
#  'self-spelling wand': 0.021312565,
#  'igor karkaroff': 0.021063676,
#  'ritchie coote': 0.021057509,
#  'fallen fifty': 0.020948347,
#  'ripper': 0.020926174,
#  'bob ogden': 0.020841397,
#  'williamson': 0.020725433,
#  'vaisey': 0.020632308,
#  'summerby': 0.020617647,
#  'urquhar': 0.020587053,
#  'sirius black i': 0.02030828,
#  "international confederation of wizards' conference": 0.01990368,
#  'millicent bulstrode': 0.019899271,
#  'moran': 0.019824892,
#  'evening prophe': 0.019708058,
#  'serpent of slytherin': 0.019457538,
#  'malcolm': 0.019437974,
#  'sturgis podmore': 0.019355789,
#  'bungy': 0.019333303,
#  'apparition instructor': 0.019221317,
#  'emma dobbs': 0.01921252,
#  'armenian warlock': 0.019122057,
#  'drooble': 0.01905093,
#  'agnes': 0.01898639,
#  'hestia jones': 0.018779207,
#  'glen': 0.018753966,
#  'iberius': 0.018603588,
#  'daily prophet grand prize galleon draw': 0.01852424,
#  'cassandra trelawney': 0.018495906,
#  'alfred cattermole': 0.018423196,
#  'mark evans': 0.018399522,
#  'gwenog jones': 0.018251263,
#  'fitness': 0.01824825,
#  'frank bryce': 0.018037345,
#  'vindictus viridian': 0.018026516,
#  'scarpin': 0.01792826,
#  'vincent crabbe': 0.01789921,
#  'junior minister': 0.01784335,
#  'maiden': 0.017721208,
#  "slytherin's locke": 0.017679852,
#  'emmeline vance': 0.01750537,
#  'lachlan the lanky': 0.01740783,
#  'bertie bo': 0.01732823,
#  'wilbert slinkhard': 0.017284343,
#  'summers': 0.017149623,
#  'potioneer': 0.017129557,
#  'blaise zabini': 0.016937826,
#  'mulle': 0.016910518,
#  'father christmas': 0.01687829,
#  'gigantic serpen': 0.016857566,
#  'gwenog': 0.016804755,
#  'matey': 0.016753355,
#  'galatea merrythough': 0.016746737,
#  'suit of armour': 0.016741242,
#  'binky': 0.01651199,
#  'penelope clearwater': 0.016465396,
#  'art historian': 0.0164395,
#  'chancellor of the exchequer': 0.0164395,
#  'eddie carmichael': 0.016438562,
#  'barnabas cuffe': 0.016379371,
#  'proudfoo': 0.01635896,
#  'pierre bonaccord': 0.016311172,
#  'davey gudgeon': 0.016299903,
#  'stewar': 0.016295303,
#  'bowman wrigh': 0.016255174,
#  'dai llewellyn': 0.01620504,
#  "roger davies's girlfriend": 0.016166387,
#  'fountain of magical brethren': 0.016033363,
#  'marius': 0.015953196,
#  'fenrir greyback': 0.015944408,
#  'he monster book of monsters': 0.0158247,
#  'petunia dursley': 0.015589314,
#  'albino peacock': 0.015564367,
#  'venomous tentacula': 0.015423157,
#  'magick moste evile': 0.015417289,
#  'mosag': 0.015408501,
#  'eric whalley': 0.015296541,
#  'greengrocer': 0.015237177,
#  'elfric the eager': 0.015200025,
#  'fawce': 0.015119093,
#  'stewart ackerley': 0.0147733865,
#  'griselda marchbanks': 0.014763957,
#  'senior undersecretary to the minister for magic': 0.014582353,
#  'assassin': 0.014355786,
#  'cole': 0.014292168,
#  'hassan mostafa': 0.014267935,
#  'veela hair': 0.014228922,
#  'billy stubbs': 0.014126057,
#  'ubbs': 0.014126057,
#  'janus thickey': 0.013945048,
#  'boris the bewildered': 0.013777188,
#  'broderick bode': 0.013596848,
#  'miles bletchley': 0.013472033,
#  'executioner': 0.013437554,
#  'he invisible book of invisibility': 0.013260527,
#  'eloise midgen': 0.013238752,
#  'bertie higgs': 0.013124442,
#  'wendelin the weird': 0.013032751,
#  'miriam strou': 0.012821667,
#  'herbert chorley': 0.0127984,
#  'squire': 0.012732953,
#  'ambrosius flume': 0.012591921,
#  'ciceron harkiss': 0.012591921,
#  'andrew kirke': 0.012103228,
#  'andrew': 0.012103228,
#  'hogwarts gobstones team': 0.01186322,
#  "pansy parkinson's gang": 0.011852662,
#  'wilfred the wistful': 0.011795261,
#  'ragnuk': 0.011783997,
#  'norberta': 0.0116309775,
#  'marlene mckinnon': 0.011581458,
#  'wo little witches': 0.011547364,
#  'african prince': 0.011538319,
#  'doris purkiss': 0.011529016,
#  'zoological column': 0.011267731,
#  'hans': 0.010807125,
#  'gordon': 0.010743422,
#  'gideon prewe': 0.010663847,
#  'cliodna': 0.010502616,
#  "riddles' cook": 0.010456358,
#  'gladys gudgeon': 0.010448563,
#  'murcus': 0.010334746,
#  'roberts': 0.010057745,
#  'kenneth towler': 0.009909486,
#  'edgar bones': 0.0097327605,
#  'edgar': 0.0097327605,
#  'registry': 0.00968058,
#  'hogwartian': 0.009448337,
#  'bradley': 0.0094337985,
#  'morfin gaun': 0.009402784,
#  'fridwulfa': 0.009037207,
#  'helena ravenclaw': 0.00896394,
#  'committee on experimental charms': 0.008933647,
#  'avery i': 0.008909277,
#  'zoo director': 0.008905118,
#  'olive hornby': 0.008824347,
#  'kevin': 0.008813608,
#  'gawain robards': 0.008799093,
#  'caradoc dearborn': 0.008751302,
#  'martin miggs': 0.008596566,
#  'fisher': 0.008538863,
#  'american plumbers': 0.008421252,
#  'wilkie twycross': 0.008362396,
#  'laura': 0.008291495,
#  'wild boar': 0.008266081,
#  'shrieking book': 0.008227035,
#  'jay': 0.008156039,
#  'heoretician': 0.008147778,
#  'wilkes': 0.008099329,
#  'marcus belby': 0.008054385,
#  'dorcas meadowes': 0.007611949,
#  'bandon banshee': 0.0073676636,
#  'picture of drunk monks': 0.007315357,
#  'cecilia': 0.0072739185,
#  'prentice': 0.007200831,
#  'curse-breaker': 0.0071971756,
#  'gloomy nuns': 0.0071337605,
#  'knight with an arrow sticking out of his forehead': 0.0071337605,
#  'gossamer': 0.0071284594,
#  'astronomy departmen': 0.0071090963,
#  'geoffrey hooper': 0.0070741675,
#  'vicky frobisher': 0.0070741675,
#  'he fates': 0.006939575,
#  'skower': 0.006935794,
#  'ali bashir': 0.0069115297,
#  'he hopping po': 0.0068118474,
#  'payne': 0.006772444,
#  'eric munch': 0.0063112844,
#  'octavius pepper': 0.0062843123,
#  'connolly': 0.006231589,
#  'hebridean black': 0.0061539086,
#  'evan rosier': 0.0061538024,
#  'dragomir gorgovitch': 0.006141513,
#  'fubster': 0.0058696223,
#  'malcolm baddock': 0.0058206413,
#  'quidditch commentator': 0.00557544,
#  'catchpole': 0.0055753235,
#  'gilbert wimple': 0.005420922,
#  'urquhart rackharrow': 0.0053687394,
#  'benjy fenwick': 0.0051774043,
#  'egbert the egregious': 0.0047374293,
#  'emeric the evil': 0.0047374293,
#  'poliakoff': 0.0046769357,
#  'fleetwood': 0.0045865825,
#  'inigo imago': 0.0045858845,
#  'loxias': 0.0043884222,
#  'daphne greengrass': 0.004157836,
#  'augustus pye': 0.004144644,
#  'augustus rookwood': 0.003976638,
#  "billy stubbs's rabbi": 0.0035763737,
#  'fergus': 0.0031498233,
#  'keeper of the reptile house': 0.0030100918,
#  'yvonne': 0.002962441,
#  'livius': 0.00288186,
#  'gable': 0.00284169,
#  'alberic grunnion': 0.0028241314,
#  'circe': 0.0028241314,
#  'hengist of woodcrof': 0.0028241314,
#  'uric the oddball': 0.0027909712,
#  'rick wand': 0.0023991133,
#  'marjorie dursley': 0.002323872,
#  'magician': 0.0022287278,
#  'dobbin': 0.0022021944,
#  'hector dagworth-granger': 0.0020584725,
#  'most extraordinary society of potioneers': 0.0020584725,
#  'hippocrates smethwyck': 0.0018974835,
#  'patricia stimpson': 0.0017694916,
#  'bertram aubrey': 0.001464119,
#  'wailing widow': 0.0010016995,
#  'erence higgs': 0.00094730174,
#  'godelo': 0.00062216586,
#  'hereward': 0.00062216586,
#  'angus flee': 0.0,
#  'angus': 0.0,
#  'hetty bayliss': 0.0,
#  'jim mcguffin': 0.0,
#  'wagga wagga werewolf': 0.0}

# %%
text = 'Marry is really so charming, who always be so nice to others'
caculate_similarity(text,1)
# Out:
# {'melinda bobbin': 0.14290757,
#  'head of slytherin house': 0.09561092,
#  'potioneer': 0.076333016,
#  'george weasley': 0.054707706,
#  'bletchley': 0.050068956,
#  'barnabas cuffe': 0.048556846,
#  'katie bell': 0.047013637,
#  'adrian pucey': 0.046913356,
#  'adrian': 0.046913356,
#  'marcus flin': 0.044829696,
#  'agnes': 0.044041242,
#  'alicia spinne': 0.043163482,
#  'assassin': 0.042555094,
#  'john': 0.03905238,
#  'eloise midgen': 0.03841446,
#  'arcus': 0.03637048,
#  'will': 0.035809044,
#  'puddifoo': 0.035426706,
#  'elfric the eager': 0.0347947,
#  'warty harris': 0.03236812,
#  'jugson': 0.031416364,
#  'hogwarts house-elves': 0.031235015,
#  'loxias': 0.03088525,
#  'pure-blood': 0.029606413,
#  'gwenog jones': 0.029208444,
#  'ed': 0.029189717,
#  'geoffrey hooper': 0.026674766,
#  'vicky frobisher': 0.026674766,
#  'eagle': 0.026364857,
#  'bas': 0.026111063,
#  'king': 0.025718555,
#  'oliver wood': 0.025440257,
#  'red': 0.02511238,
#  'lima': 0.024527758,
#  'bob': 0.02437076,
#  'gwenog': 0.024220647,
#  'ar': 0.023047669,
#  'dan': 0.022958828,
#  'malcolm': 0.022922853,
#  'ned': 0.021964839,
#  'werewolf': 0.021261591,
#  'angel': 0.020952746,
#  'healer': 0.020445967,
#  'commen': 0.020405468,
#  'harry potter ': 0.020334344,
#  'fred weasley': 0.020310337,
#  'he toad': 0.01973824,
#  'im': 0.019701691,
#  'parvati patil': 0.019625358,
#  'good news': 0.01875255,
#  'bean': 0.018659215,
#  'dragon keeper': 0.018319923,
#  'coun': 0.018206133,
#  'seer': 0.017873654,
#  'karkus': 0.017494353,
#  'mina': 0.017461676,
#  'michael corner': 0.017212877,
#  'alber': 0.017191205,
#  'bell': 0.015817786,
#  'snowy': 0.0155334715,
#  'name': 0.0148532335,
#  'magorian': 0.0147792855,
#  'do': 0.0146476915,
#  'scabior': 0.014553075,
#  'chas': 0.014310688,
#  'zonko': 0.013964126,
#  'michael': 0.013550943,
#  'om': 0.012766553,
#  'lavender brown': 0.012701658,
#  'queen': 0.012684716,
#  'wandless': 0.0125942,
#  'lee jordan': 0.012471931,
#  'luna lovegood': 0.012084005,
#  'mark': 0.011859688,
#  'roy': 0.011686208,
#  'angelina johnson': 0.011577744,
#  'ronald weasley': 0.011402444,
#  'wand': 0.011392991,
#  'horace': 0.011239776,
#  'zacharias smith': 0.011167845,
#  'health': 0.011134973,
#  'frank': 0.010999035,
#  'roll': 0.01069399,
#  'opinion': 0.010685585,
#  'follo': 0.010663852,
#  'muggle-born': 0.010451505,
#  'golgomath': 0.010298421,
#  'hall': 0.010089235,
#  'gian': 0.00979778,
#  'spindle': 0.009778456,
#  'unicorn': 0.00965395,
#  'salazar slytherin': 0.00963866,
#  'badger': 0.009319141,
#  'prime minister': 0.008792143,
#  'prince': 0.008773283,
#  'minister': 0.008729316,
#  'gellert grindelwald': 0.008696551,
#  'anthony goldstein': 0.008639945,
#  'dementor': 0.008470623,
#  'colin creevey': 0.008452549,
#  'harry potter': 0.008442558,
#  'argus filch': 0.008316411,
#  'professor': 0.008222678,
#  'centaur': 0.008186205,
#  'ofty': 0.008176505,
#  'rita skeeter': 0.007978515,
#  'asha': 0.007964549,
#  'arthur': 0.007940989,
#  'finch': 0.007904882,
#  'auror': 0.007869764,
#  'muriel': 0.007833274,
#  'dudley': 0.0076464415,
#  'brown': 0.007632669,
#  'house-elf': 0.0074023567,
#  'horcru': 0.0073989704,
#  'peeves': 0.0073392834,
#  'fred and george weasley': 0.007240024,
#  'lion': 0.007237021,
#  'hermione granger': 0.007161022,
#  'harper': 0.007026486,
#  'bem': 0.0070061153,
#  'godric gryffindor': 0.0069129253,
#  'marsh': 0.0068599004,
#  'jack': 0.0067586615,
#  'gargoyle': 0.006746834,
#  'portrai': 0.006576932,
#  'dobby': 0.0063840863,
#  'millicent bulstrode': 0.0063116406,
#  'half-blood': 0.0062869187,
#  'god': 0.0062614935,
#  'goyle': 0.006248784,
#  'kreacher': 0.006221987,
#  'lucius malfoy': 0.00611467,
#  'om riddle': 0.0059906,
#  'savage': 0.0058989786,
#  'basil': 0.005521178,
#  'horace slughorn': 0.005325238,
#  'viktor krum': 0.005303546,
#  'viole': 0.0052309516,
#  'hestral': 0.0052245418,
#  'fawkes': 0.0051984647,
#  'sorting ha': 0.005034608,
#  'bellatrix lestrange': 0.0049696397,
#  'pansy parkinson': 0.004857909,
#  'pike': 0.004835124,
#  'squib': 0.004783228,
#  'bane': 0.004704115,
#  'neville longbottom': 0.004608992,
#  'cho chang': 0.004539853,
#  'severus snape': 0.004490433,
#  'crabbe': 0.00443415,
#  'buckbeak': 0.0043969397,
#  'nagini': 0.004265641,
#  'fleur delacour': 0.0037572938,
#  'winky': 0.003570247,
#  'lestrange': 0.0035475018,
#  'borgin': 0.00352197,
#  'gringo': 0.0033841822,
#  'cedric diggory': 0.003375256,
#  'griphook': 0.0033706494,
#  'aragog': 0.0032969725,
#  'gilderoy lockhar': 0.003279057,
#  'snake': 0.00324147,
#  'bush': 0.0031222613,
#  'draco malfoy': 0.0029293709,
#  'cedric': 0.002867791,
#  'hedwig': 0.0027782673,
#  'fang': 0.0026744164,
#  'rosmerta': 0.0025474126,
#  'dark mark': 0.0023652331,
#  'grawp': 0.0019163302,
#  'nigel': 0.0018420261,
#  'albus dumbledore': 0.0017536206,
#  'crookshanks': 0.0012135332,
#  'abbo': 0.0,
#  'aberforth dumbledore': 0.0,
#  'abraxas malfoy': 0.0,
#  'acromantula': 0.0,
#  'adalbert waffling': 0.0,
#  'african prince': 0.0,
#  'aged witch': 0.0,
#  'alastor moody': 0.0,
#  'alberic grunnion': 0.0,
#  'albino peacock': 0.0,
#  'alderton': 0.0,
#  'alecto carrow': 0.0,
#  'alfred cattermole': 0.0,
#  'ali bashir': 0.0,
#  'alice longbottom': 0.0,
#  'alice': 0.0,
#  'alys': 0.0,
#  'ambrosius flume': 0.0,
#  'amelia bones': 0.0,
#  'american plumbers': 0.0,
#  'amos diggory': 0.0,
#  'amy benson': 0.0,
#  'andrew kirke': 0.0,
#  'andrew': 0.0,
#  'angus flee': 0.0,
#  'angus': 0.0,
#  'animagus': 0.0,
#  'antonin dolohov': 0.0,
#  'apparition instructor': 0.0,
#  'arabella figg': 0.0,
#  'ariana dumbledore': 0.0,
#  'arkie alderton': 0.0,
#  'armando dippe': 0.0,
#  'armenian warlock': 0.0,
#  'arnold': 0.0,
#  'arsenius jigger': 0.0,
#  'art historian': 0.0,
#  'arthur weasley': 0.0,
#  'astronomy departmen': 0.0,
#  'augusta longbottom': 0.0,
#  'augustus pye': 0.0,
#  'augustus rookwood': 0.0,
#  'avery i': 0.0,
#  'bad news': 0.0,
#  'bagsho': 0.0,
#  'bandon banshee': 0.0,
#  'barnabas the barmy': 0.0,
#  'barnabus finkley': 0.0,
#  'barry ryan': 0.0,
#  'baruffio': 0.0,
#  'bathilda bagsho': 0.0,
#  'beedle the bard': 0.0,
#  'benjy fenwick': 0.0,
#  'bernie': 0.0,
#  'bertha jorkins': 0.0,
#  'bertie bo': 0.0,
#  'bertie higgs': 0.0,
#  'bertram aubrey': 0.0,
#  'bilius': 0.0,
#  "billy stubbs's rabbi": 0.0,
#  'billy stubbs': 0.0,
#  'binky': 0.0,
#  'black knigh': 0.0,
#  'blackthorn wand': 0.0,
#  'blaise zabini': 0.0,
#  'blood traitor': 0.0,
#  'bloody baron': 0.0,
#  'bob ogden': 0.0,
#  'bodrod the bearded': 0.0,
#  'bogrod': 0.0,
#  'boris the bewildered': 0.0,
#  'bowman wrigh': 0.0,
#  'bozo': 0.0,
#  'bradley': 0.0,
#  'brian': 0.0,
#  'broderick bode': 0.0,
#  'brutus': 0.0,
#  'bungy': 0.0,
#  'cadogan': 0.0,
#  'cadwallader': 0.0,
#  'caractacus burke': 0.0,
#  'caractacus': 0.0,
#  'caradoc dearborn': 0.0,
#  'cassandra trelawney': 0.0,
#  'cassandra vablatsky': 0.0,
#  'catchpole': 0.0,
#  'cecilia': 0.0,
#  'celestina warbeck': 0.0,
#  'chambers': 0.0,
#  'chancellor of the exchequer': 0.0,
#  'charity burbage': 0.0,
#  'charlie g': 0.0,
#  'ciceron harkiss': 0.0,
#  'circe': 0.0,
#  'cliodna': 0.0,
#  'cole': 0.0,
#  'committee on experimental charms': 0.0,
#  'connolly': 0.0,
#  'cormac mclaggen': 0.0,
#  'cornelius fudge': 0.0,
#  'court scribe': 0.0,
#  'curse-breaker': 0.0,
#  'dai llewellyn': 0.0,
#  'daily prophet grand prize galleon draw': 0.0,
#  'daphne greengrass': 0.0,
#  'davey gudgeon': 0.0,
#  'dean thomas': 0.0,
#  'dedalus diggle': 0.0,
#  'demelza robins': 0.0,
#  'dennis bishop': 0.0,
#  'dennis creevey': 0.0,
#  'dennis': 0.0,
#  'dentis': 0.0,
#  "devil's snare": 0.0,
#  'devil': 0.0,
#  'dexter fortescue': 0.0,
#  'dilys derwen': 0.0,
#  'dirk cresswell': 0.0,
#  'dirk': 0.0,
#  'dobbin': 0.0,
#  'dolores umbridge': 0.0,
#  'dorcas meadowes': 0.0,
#  'doris crockford': 0.0,
#  'doris purkiss': 0.0,
#  'dougal': 0.0,
#  "draco malfoy's eagle owl": 0.0,
#  'dragomir gorgovitch': 0.0,
#  'drooble': 0.0,
#  'dudley dursley': 0.0,
#  'eagle door knocker': 0.0,
#  'eddie carmichael': 0.0,
#  'edgar bones': 0.0,
#  'edgar': 0.0,
#  'edgecombe': 0.0,
#  'egbert the egregious': 0.0,
#  'eileen prince': 0.0,
#  'eldred worple': 0.0,
#  'elfrida cragg': 0.0,
#  'eliza': 0.0,
#  'elphias doge': 0.0,
#  'emeric the evil': 0.0,
#  'emma dobbs': 0.0,
#  'emmeline vance': 0.0,
#  'enid smeek': 0.0,
#  'eric munch': 0.0,
#  'eric whalley': 0.0,
#  'errol': 0.0,
#  'euan abercrombie': 0.0,
#  'evan rosier': 0.0,
#  'evening prophe': 0.0,
#  'everard': 0.0,
#  'executioner': 0.0,
#  'fabian prewe': 0.0,
#  'fallen fifty': 0.0,
#  'fat friar': 0.0,
#  'fat lady': 0.0,
#  'father christmas': 0.0,
#  'fawce': 0.0,
#  'fenrir greyback': 0.0,
#  'fergus': 0.0,
#  'filibuster': 0.0,
#  'finn': 0.0,
#  'firenze': 0.0,
#  'fisher': 0.0,
#  'fitness': 0.0,
#  'fleetwood': 0.0,
#  'florean fortescue': 0.0,
#  'florence': 0.0,
#  'fluffy': 0.0,
#  'flurry': 0.0,
#  'forecas': 0.0,
#  'fortress': 0.0,
#  'fountain of magical brethren': 0.0,
#  'frank bryce': 0.0,
#  'frank longbottom': 0.0,
#  'friar': 0.0,
#  'fridwulfa': 0.0,
#  'fubster': 0.0,
#  'gable': 0.0,
#  'galatea merrythough': 0.0,
#  'games': 0.0,
#  'gamp': 0.0,
#  'gang of slytherins': 0.0,
#  'gawain robards': 0.0,
#  'gibbon': 0.0,
#  'gideon prewe': 0.0,
#  'gigantic serpen': 0.0,
#  'gilbert wimple': 0.0,
#  'gladys gudgeon': 0.0,
#  'glen': 0.0,
#  'gloomy nuns': 0.0,
#  'glossy': 0.0,
#  'goblet of fire': 0.0,
#  'godelo': 0.0,
#  'golpalo': 0.0,
#  'gordon': 0.0,
#  'gornuk': 0.0,
#  'gossamer': 0.0,
#  'greengrocer': 0.0,
#  'gregory goyle': 0.0,
#  'gregory the smarmy': 0.0,
#  'griffin': 0.0,
#  'griselda marchbanks': 0.0,
#  'grumble': 0.0,
#  'half-breed': 0.0,
#  'half-gian': 0.0,
#  'hannah abbo': 0.0,
#  'hans': 0.0,
#  'harold dingle': 0.0,
#  'hassan mostafa': 0.0,
#  'head of departmen': 0.0,
#  'head of gryffindor house': 0.0,
#  'head of hufflepuff house': 0.0,
#  'headless hun': 0.0,
#  'heady': 0.0,
#  'heather': 0.0,
#  'hebridean black': 0.0,
#  'hector dagworth-granger': 0.0,
#  'helena ravenclaw': 0.0,
#  'helga hufflepuff': 0.0,
#  'hengist of woodcrof': 0.0,
#  'hepzibah smith': 0.0,
#  'herbert chorley': 0.0,
#  'hereward': 0.0,
#  'hermes': 0.0,
#  'hestia jones': 0.0,
#  'hetty bayliss': 0.0,
#  'hippocrates smethwyck': 0.0,
#  'hogwartian': 0.0,
#  'hogwarts gobstones team': 0.0,
#  'hokey': 0.0,
#  "hufflepuff's cup": 0.0,
#  'humphrey belcher': 0.0,
#  'ignotus peverell': 0.0,
#  'igor karkaroff': 0.0,
#  'inde': 0.0,
#  'inferius': 0.0,
#  'inigo imago': 0.0,
#  "international confederation of wizards' conference": 0.0,
#  'international': 0.0,
#  'ivor dillonsby': 0.0,
#  'jack sloper': 0.0,
#  'james potter i': 0.0,
#  'janus thickey': 0.0,
#  'jay': 0.0,
#  'jim mcguffin': 0.0,
#  'jim': 0.0,
#  'jimmy peakes': 0.0,
#  'joey jenkins': 0.0,
#  'junior minister': 0.0,
#  'justin finch-fletchley': 0.0,
#  'keeper of the reptile house': 0.0,
#  'kendra dumbledore': 0.0,
#  'kenneth towler': 0.0,
#  'kevin': 0.0,
#  'kingsley shacklebol': 0.0,
#  'knight with an arrow sticking out of his forehead': 0.0,
#  'knigh': 0.0,
#  'lachlan the lanky': 0.0,
#  'laura': 0.0,
#  'leanne': 0.0,
#  'leprechaun': 0.0,
#  'libatius borage': 0.0,
#  'livius': 0.0,
#  'ludovic bagman': 0.0,
#  'luke': 0.0,
#  'mafalda hopkirk': 0.0,
#  'mafalda': 0.0,
#  'magician': 0.0,
#  'magick moste evile': 0.0,
#  'maiden': 0.0,
#  'malcolm baddock': 0.0,
#  'malkin': 0.0,
#  'mandrake': 0.0,
#  "marauder's map": 0.0,
#  'marcus belby': 0.0,
#  'marietta edgecombe': 0.0,
#  'marius': 0.0,
#  'marjorie dursley': 0.0,
#  'mark evans': 0.0,
#  'marlene mckinnon': 0.0,
#  'martin miggs': 0.0,
#  "marvolo gaunt's ring": 0.0,
#  'marvolo gaun': 0.0,
#  'mary cattermole': 0.0,
#  'mary dorkins': 0.0,
#  'mary macdonald': 0.0,
#  'mary': 0.0,
#  'mason': 0.0,
#  'matey': 0.0,
#  'merlin': 0.0,
#  'merope riddle': 0.0,
#  'metamorphmagus': 0.0,
#  'miles bletchley': 0.0,
#  'millicent bagnold': 0.0,
#  'mills': 0.0,
#  'minerva mcgonagall': 0.0,
#  'minerva': 0.0,
#  'miranda goshawk': 0.0,
#  'miriam strou': 0.0,
#  'molly weasley': 0.0,
#  'montgomery sisters': 0.0,
#  'montgomery': 0.0,
#  'morag': 0.0,
#  'moran': 0.0,
#  'morfin gaun': 0.0,
#  'mosag': 0.0,
#  'most extraordinary society of potioneers': 0.0,
#  'mountain troll': 0.0,
#  'mrs norris': 0.0,
#  'muggle ar': 0.0,
#  'mulle': 0.0,
#  'mundungus fletcher': 0.0,
#  'murcus': 0.0,
#  'narcissa malfoy': 0.0,
#  'nash': 0.0,
#  'nicholas de mimsy-porpington': 0.0,
#  'nicolas flamel': 0.0,
#  'non-magic people': 0.0,
#  'norberta': 0.0,
#  'no': 0.0,
#  'nymphadora tonks': 0.0,
#  'octavius pepper': 0.0,
#  'olive hornby': 0.0,
#  'opposition': 0.0,
#  'oswald': 0.0,
#  'padma patil': 0.0,
#  "pansy parkinson's gang": 0.0,
#  'parseltongue': 0.0,
#  'patricia stimpson': 0.0,
#  'patrick delaney-podmore': 0.0,
#  'patrick': 0.0,
#  'payne': 0.0,
#  'penelope clearwater': 0.0,
#  'percy weasley': 0.0,
#  'peter pettigrew': 0.0,
#  'peter': 0.0,
#  'petunia dursley': 0.0,
#  'peverell brothers': 0.0,
#  'phineas nigellus black': 0.0,
#  'phyllida spore': 0.0,
#  'picture of drunk monks': 0.0,
#  'pierre bonaccord': 0.0,
#  'piers polkiss': 0.0,
#  'pius thicknesse': 0.0,
#  'poliakoff': 0.0,
#  'police': 0.0,
#  'poppy': 0.0,
#  'portly ghos': 0.0,
#  'prentice': 0.0,
#  'pringle': 0.0,
#  'proudfoo': 0.0,
#  'ptolemy': 0.0,
#  'quentin trimble': 0.0,
#  'quidditch captain': 0.0,
#  'quidditch commentator': 0.0,
#  'quidditch referee': 0.0,
#  'ragnok': 0.0,
#  'ragnuk': 0.0,
#  'reginald cattermole': 0.0,
#  'registry': 0.0,
#  'regulus black': 0.0,
#  'remus lupin': 0.0,
#  "riddles' cook": 0.0,
#  'ripper': 0.0,
#  'ritchie coote': 0.0,
#  'roberts': 0.0,
#  'rodolphus lestrange': 0.0,
#  "roger davies's girlfriend": 0.0,
#  'roger davies': 0.0,
#  'romilda vane': 0.0,
#  'ronan': 0.0,
#  'rosie': 0.0,
#  'rowena ravenclaw': 0.0,
#  'rubeus hagrid': 0.0,
#  'rufus scrimgeour': 0.0,
#  'runcorn': 0.0,
#  'scarpin': 0.0,
#  'scrivenshaf': 0.0,
#  'seamus finnigan': 0.0,
#  'secret keeper': 0.0,
#  'security troll': 0.0,
#  'self-spelling wand': 0.0,
#  'selwyn': 0.0,
#  'senior undersecretary to the minister for magic': 0.0,
#  'serpent of slytherin': 0.0,
#  'shrieking book': 0.0,
#  'shrunken head': 0.0,
#  'sinistra': 0.0,
#  'sirius black i': 0.0,
#  'sirius black': 0.0,
#  'skower': 0.0,
#  "slytherin's locke": 0.0,
#  'snargaluff': 0.0,
#  'spellman': 0.0,
#  'sphin': 0.0,
#  'sports': 0.0,
#  'squire': 0.0,
#  'stanley shunpike': 0.0,
#  'stark': 0.0,
#  'stewart ackerley': 0.0,
#  'stewar': 0.0,
#  'stubby boardman': 0.0,
#  'stunned death eater': 0.0,
#  'sturgis podmore': 0.0,
#  'suit of armour': 0.0,
#  'summerby': 0.0,
#  'summers': 0.0,
#  'sunday prophe': 0.0,
#  'susan bones': 0.0,
#  'sword of gryffindor': 0.0,
#  'sybill trelawney': 0.0,
#  'alking mirror': 0.0,
#  'erence higgs': 0.0,
#  'erry boo': 0.0,
#  'he fates': 0.0,
#  'he hopping po': 0.0,
#  'he invisible book of invisibility': 0.0,
#  'he monster book of monsters': 0.0,
#  'heodore no': 0.0,
#  'heoretician': 0.0,
#  'horfinn rowle': 0.0,
#  'iberius': 0.0,
#  'obias snape': 0.0,
#  'om riddle senior': 0.0,
#  'ravers': 0.0,
#  'revor': 0.0,
#  'rick wand': 0.0,
#  'rio': 0.0,
#  'roupe of dancing skeletons': 0.0,
#  'ubbs': 0.0,
#  'ufty': 0.0,
#  'urner': 0.0,
#  'u': 0.0,
#  'winkle': 0.0,
#  'wo little witches': 0.0,
#  'ubbly': 0.0,
#  'ugga': 0.0,
#  'urg the unclean': 0.0,
#  'uric the oddball': 0.0,
#  'urquhart rackharrow': 0.0,
#  'urquhar': 0.0,
#  'vaisey': 0.0,
#  'veela hair': 0.0,
#  'venomous tentacula': 0.0,
#  'vernon dursley': 0.0,
#  'veronica smethley': 0.0,
#  'vincent crabbe': 0.0,
#  'vindictus viridian': 0.0,
#  'wagga wagga werewolf': 0.0,
#  'wailing widow': 0.0,
#  'wakanda': 0.0,
#  'walden macnair': 0.0,
#  'wandmaker': 0.0,
#  'wealthy man who owned the riddle house': 0.0,
#  'wendelin the weird': 0.0,
#  'wilbert slinkhard': 0.0,
#  'wild boar': 0.0,
#  'wilfred the wistful': 0.0,
#  'wilkes': 0.0,
#  'wilkie twycross': 0.0,
#  'williamson': 0.0,
#  'willy widdershins': 0.0,
#  'wizarding wireless network news': 0.0,
#  'wool': 0.0,
#  'enophilius lovegood': 0.0,
#  'young woman': 0.0,
#  'yvonne': 0.0,
#  'zoo director': 0.0,
#  'zoological column': 0.0}

# %%
one2one_similarity('harry potter','who is so handsome and really nice guy',1)
# Out:
# 0.003661337
